# %% [markdown]
# # Part 1: Reading Files
#
#
# 1. chinook.db
#
# - Use the sqlite3 library to connect to the database.
# Read the customers table into a pandas DataFrame. Display the first 10 rows.
#
# 2. iris.json
#
# - Load the JSON file into a DataFrame. Show the shape of the dataset and the column names.
#
# 3. titanic.xlsx
#
# - Load the Excel file into a DataFrame. Use head to display the first 5 rows.
#
# 4. Flights parquet file
#
# - Read the Parquet file into a DataFrame and use info to summarize it.
#
# 5. movie.csv
#
# - Load the CSV file into a DataFrame and display a random sample of 10 rows.

# %%
import sqlite3
import pandas as pd

# Connect the chinook.db database, and read it into DataFrame
with sqlite3.connect('data/chinook1.db') as connection:
    df_employee = pd.read_sql("SELECT * FROM customers", con=connection)

# Display the first 10 rows
df_employee.head(10)
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
# 5           6     Helena         Holý
# 6           7     Astrid       Gruber
# 7           8       Daan      Peeters
# 8           9       Kara      Nielsen
# 9          10    Eduardo      Martins
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# ...

# %% [markdown]
# 2. iris.json
#
# - Load the JSON file into a DataFrame. Show the shape of the dataset and the column names.

# %%
import json
import pandas as pd

# Read json file into dataframe
df_iris = pd.read_json('data/iris.json')

# Show the shape of the dataset and the column names.
df_iris.shape
df_iris.columns
# Out:
# Index(['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth', 'species'], dtype='object')

# %% [markdown]
# 3. titanic.xlsx
#
# - Load the Excel file into a DataFrame. Use head to display the first 5 rows.

# %%
import pandas as pd

# Load the Excel file into a DataFrame
df_titanic = pd.read_excel('data/titanic.xlsx')

# Display the first 5 rows
df_titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd

# Read the Parquet file into a DataFrame
flights_df = pd.read_parquet("flights.parquet")

# Summarize the DataFrame using the info method
flights_df.info()


# I could't upload this file from github, but the code is like that.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 4
#       1 import pandas as pd
#       3 # Read the Parquet file into a DataFrame
# ----> 4 flights_df = pd.read_parquet("flights.parquet")
#       6 # Summarize the DataFrame using the info method
#       7 flights_df.info()
#
# File c:\Users\Mezon\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
# ...

# %% [markdown]
# 5. movie.csv
#
# - Load the CSV file into a DataFrame and display a random sample of 10 rows.

# %%
import csv
import pandas as pd

# Load the CSV file into a DataFrame.
df_movie = pd.read_csv('data/movie.csv')

# 10 random sample
df_movie.sample(10)
# Out:
#       color           director_name  num_critic_for_reviews  duration  \
# 4408  Color  Justin Thomas Ostensen                    18.0      99.0
# 246   Color              Josh Trank                   369.0     100.0
# 2225  Color      Michael J. Bassett                   173.0      95.0
# 4675  Color            Eric England                    15.0      81.0
# 1348  Color              Jeb Stuart                    38.0     118.0
# 4720  Color          Florence Ayisi                    27.0     104.0
# 202   Color          Gore Verbinski                   271.0     143.0
# 3140  Color            Victor Salva                    44.0     120.0
# 2414  Color              Jeff Kanew                    11.0     105.0
# 1895  Color         Cathy Malkasian                    38.0      85.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 4408                      0.0                     5.0       Kristin Booth
# ...
